# %%
from IPython.display import Image 
Image('./basic-auth.png')

# %% [markdown]
# username + password
# Basic Authorization
#
# 认证核心就是每次请求是都必须使用该用户的uasename和password。
# headers: {
#     'Authorization': 'Basic ' + base64(username + ":" + password)
#  }
# ==>
# Authorization： BasicYWRtaW46T25lVGlubWFuT25lRHJlYW02Ng==
#
# 如何解析：

# %%
import base64
print(base64.b64encode(b'username:password'))
# dXNlcm5hbWU6cGFzc3dvcmQ=
print(base64.b64decode(b'dXNlcm5hbWU6cGFzc3dvcmQ='))
# Out:
# b'dXNlcm5hbWU6cGFzc3dvcmQ='
# b'username:password'
