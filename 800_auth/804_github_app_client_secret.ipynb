# %% [markdown]
# https://docs.github.com/en/rest/guides/basics-of-authentication
#
# https://github.com/github/platform-samples/blob/master/api/python/building-a-ci-server/server.py

# %% [markdown]
# Your client ID and client secret keys come from your application's configuration page. You should never, ever store these values in GitHub--or any other public place, for that matter. We recommend storing them as environment variables

# %% [markdown]
#  running a regular server:
#  http://127.0.0.1:4567
#  Go to Authorize Page

# %%
from IPython.display import Image 
Image('./authorize-app.png')

# %% [markdown]
# After click Authorize application
# Go to callback URL as http://127.0.0.1:4567/callback
# It's the callback URL that GitHub returns the user to after successful authentication.
# After success GitHub provides a temporary code value.
# You'll need to POST this code back to GitHub in exchange for an access_token.
#
# def callback():
#     code = requst.json()['code']
#
# def get_token():
#     post('https://github.com/login/oauth/access_token',
#                             {:client_id => CLIENT_ID,
#                             :client_secret => CLIENT_SECRET,
#                             :code => session_code},
#                             :accept => :json)
#     return acceess_token
#
# def request():
#     method('url',
#          {:params => {:access_token => access_token}})
